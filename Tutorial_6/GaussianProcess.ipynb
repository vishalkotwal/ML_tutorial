# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import math
import random

# %%
def dataSet():
    X_train = np.array([-4, -3, -2, -1, 1]).reshape(-1, 1)
    Y_train = np.sin(X_train)
    X_test = np.arange(-5, 5, 0.2).reshape(-1, 1)
    return X_train,Y_train,X_test

# %%
def kernel(X1,X2, scale=1.0, sigma_f = 1.0):
    sqdist = np.sum(X1 ** 2 ,1).reshape(-1,1) + np.sum(X2**2,1) - 2 * np.dot(X1,X2.T)
    return sigma_f**2  * np.exp(-0.5 / scale**2  * sqdist)

# %%
def gaussian_process(mu, cov, X, X_train=None, Y_train=None, samples=[]):
    X = X.ravel()
    mu = mu.ravel()
    uncertainty = 1.96 * np.sqrt(np.diag(cov))
    plt.fill_between(X, mu + uncertainty, mu - uncertainty, alpha=0.1)
    plt.plot(X, mu, label='Mean')
    for i, sample in enumerate(samples):
        plt.plot(X, sample, lw=1, ls='--', label=f'Sample {i+1}')
    if X_train is not None:
        plt.plot(X_train, Y_train, 'rx')
    plt.plot(X_train,Y_train,label='True')    
    plt.legend()

# %%
X_train,Y_train,X_test =  dataSet()

# %%
beta = 25
C = kernel(X_train,X_train)
k = kernel(X_train,X_test)
c = kernel(X_test,X_test)

C = C + np.eye(C.shape[0])* (1/beta)
L = np.linalg.cholesky(C)
alpha = np.dot(np.linalg.inv(L.T),np.dot(np.linalg.inv(L),Y_train))
f = np.dot(k.T , alpha)
v = np.dot(np.linalg.inv(L) , k)
var = c - np.dot(v.T,v)

# %%
plt.plot(X_train,Y_train,label='True')

# %%
gaussian_process(f, var, X_test, X_train, Y_train)

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 12))
sns.heatmap(C, ax=axes[0, 0])
sns.heatmap(k, ax=axes[0, 1])
sns.heatmap(k.T, ax=axes[1, 0])
sns.heatmap(c, ax=axes[1, 1])

# %%
#cn1 = cn+1
Cn1 = np.vstack((np.hstack((C, k)), np.hstack((k.T, c))))
sns.heatmap(Cn1)
